# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
a = pd.read_excel("부문별 온실가스 배출량.xls")
b = pd.read_excel("연도별 온실가스 배출량 (1).xls")
c = pd.read_excel("연도별 온실가스 배출량 (2).xls")
d = pd.read_excel("온실가스 배출량.xlsx")
e = pd.read_csv("대한민국CO2배출량.csv")
car = pd.read_csv("cars.csv", encoding = "CP949")

#2018년 부문별 온실가스 배출량
a.head()
# Out:
#      연도 국가/지역          총배출량      전력 및 열생산   기타 에너지 산업    제조업 및 건설업  \
# 0  2018   전세계  33336.375612  13977.831481  1613.12308  6158.315561
#
#         교통(기타)       교통(도로)           기타
# 0  2167.329291  6090.404922  3329.371277

# %%
a.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   연도         1 non-null      int64
#  1   국가/지역      1 non-null      object
#  2   총배출량       1 non-null      float64
#  3   전력 및 열생산   1 non-null      float64
#  4   기타 에너지 산업  1 non-null      float64
#  5   제조업 및 건설업  1 non-null      float64
#  6   교통(기타)     1 non-null      float64
#  7   교통(도로)     1 non-null      float64
#  8   기타         1 non-null      float64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 200.0+ bytes

# %%
# 연도별 교통부문별 온실가스 배출량(2009~2018)
b.head()
# Out:
#          부문            합계          2009          2010          2011  \
# 0     Total  9.313755e+08  8.648702e+07  9.188583e+07  8.942128e+07
# 1      Road  8.735678e+08  8.065459e+07  8.349902e+07  8.309510e+07
# 2  Railroad  2.517001e+07  2.761223e+06  1.986671e+06  2.862746e+06
# 3  Aviation  1.902367e+07  1.084874e+06  6.052340e+06  1.229149e+06
# 4  Shipping  1.361403e+07  1.986343e+06  3.477987e+05  2.234287e+06
#
#            2012          2013          2014          2015          2016  \
# 0  8.843068e+07  9.045161e+07  8.893694e+07  9.750790e+07  9.712282e+07
# 1  8.241573e+07  8.498843e+07  8.410100e+07  8.887149e+07  9.278889e+07
# 2  2.650830e+06  2.712035e+06  2.515252e+06  2.497294e+06  2.583731e+06
# 3  1.250882e+06  1.331817e+06  1.331817e+06  1.614928e+06  1.750194e+06
# 4  2.113230e+06  1.419324e+06  9.888687e+05  4.524180e+06  0.000000e+00
#
#            2017          2018
# 0  9.587173e+07  1.052597e+08
# 1  9.225377e+07  1.008997e+08
# ...

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   부문      5 non-null      object
#  1   합계      5 non-null      float64
#  2   2009    5 non-null      float64
#  3   2010    5 non-null      float64
#  4   2011    5 non-null      float64
#  5   2012    5 non-null      float64
#  6   2013    5 non-null      float64
#  7   2014    5 non-null      float64
#  8   2015    5 non-null      float64
#  9   2016    5 non-null      float64
#  10  2017    5 non-null      float64
#  11  2018    5 non-null      float64
# dtypes: float64(11), object(1)
# memory usage: 608.0+ bytes

# %%
#전세계 연도별 온실가스 배출량(1990~2018)
c.head()
# Out:
#   국가/지역          1990         1991          1992          1993          1994  \
# 0   전세계  20516.043089  20640.47909  20580.820278  20698.466727  20798.570472
#
#            1995          1996          1997          1998  ...          2009  \
# 0  21372.500362  21824.551347  22218.764468  22394.399227  ...  28792.054771
#
#            2010          2011          2012          2013          2014  \
# 0  30582.363497  31459.469819  31805.959479  32370.661014  32388.573452
#
#            2015          2016          2017          2018
# 0  32365.537564  32374.686522  32837.419865  33513.253006
#
# [1 rows x 30 columns]

# %%
c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 30 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국가/지역   1 non-null      object
#  1   1990    1 non-null      float64
#  2   1991    1 non-null      float64
#  3   1992    1 non-null      float64
#  4   1993    1 non-null      float64
#  5   1994    1 non-null      float64
#  6   1995    1 non-null      float64
#  7   1996    1 non-null      float64
#  8   1997    1 non-null      float64
#  9   1998    1 non-null      float64
#  10  1999    1 non-null      float64
#  11  2000    1 non-null      float64
#  12  2001    1 non-null      float64
#  13  2002    1 non-null      float64
#  14  2003    1 non-null      float64
#  15  2004    1 non-null      float64
#  16  2005    1 non-null      float64
#  17  2006    1 non-null      float64
#  18  2007    1 non-null      float64
#  19  2008    1 non-null      float64
#  20  2009    1 non-null      float64
# ...

# %%
#국가별 온실가스 배출량(2016~2020)
d.head()
# Out:
#          국가별      2016      2017      2018      2019      2020
# 0        국가별  온실가스 배출량  온실가스 배출량  온실가스 배출량  온실가스 배출량  온실가스 배출량
# 1        아시아       NaN       NaN       NaN       NaN       NaN
# 2    　　　대한민국     596.9     608.1       614     593.7     578.6
# 3  　　　아제르바이잔      38.5      37.7      38.6      41.8      40.9
# 4     　　　바레인      34.5      34.7      34.9      37.6         -

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94 entries, 0 to 93
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국가별     94 non-null     object
#  1   2016    88 non-null     object
#  2   2017    88 non-null     object
#  3   2018    88 non-null     object
#  4   2019    88 non-null     object
#  5   2020    88 non-null     object
# dtypes: object(6)
# memory usage: 4.5+ KB

# %%
#한국의 배출원별 탄소배출량(1980~2019)
e.head()
# Out:
#    Series Name  Coal and coke CO2 emissions, South Korea, Annual  \
# 0         1980                                                66
# 1         1981                                                75
# 2         1982                                                79
# 3         1983                                                81
# 4         1984                                                92
#
#    Petroleum and other liquids CO2 emissions, South Korea, Annual  \
# 0                                                 73
# 1                                                 71
# 2                                                 71
# 3                                                 73
# 4                                                 78
#
#    CO2 emissions, South Korea, Annual  \
# 0                                 139
# 1                                 146
# 2                                 149
# 3                                 154
# 4                                 169
#
# ...

# %%
e.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 5 columns):
#  #   Column                                                          Non-Null Count  Dtype
# ---  ------                                                          --------------  -----
#  0   Series Name                                                     40 non-null     int64
#  1   Coal and coke CO2 emissions, South Korea, Annual                40 non-null     int64
#  2   Petroleum and other liquids CO2 emissions, South Korea, Annual  40 non-null     int64
#  3   CO2 emissions, South Korea, Annual                              40 non-null     int64
#  4   Consumed natural gas CO2 emissions, South Korea, Annual         40 non-null     float64
# dtypes: float64(1), int64(4)
# memory usage: 1.7 KB

# %% [markdown]
# # 데이터 정제

# %%
#d의 숫자가 아닌 데이터 확인
print("2016: ",d.iloc[:,1].unique())
print("2017: ",d.iloc[:,2].unique())
print("2018: ",d.iloc[:,3].unique())
print("2019: ",d.iloc[:,4].unique())
print("2020: ",d.iloc[:,5].unique())
# Out:
# 2016:  ['온실가스 배출량' nan 596.9 38.5 34.5 86.7 8.4 9851 2177.2 514.2 770.9 251.8
#  64.3 1157.5 23.9 226 114 25.8 236.4 87.9 191.7 116.7 104.3 618.5 32.2 258
#  140.1 222 122.9 201.7 12 609.7 496.2 5239.7 201.1 27.8 460 87.7 93.2 27.7
#  45.5 7.5 57.5 23.7 6.6 288 36.1 16.2 316.5 749 336.2 160.1 39.6 301.2
#  72.6 2018.2 14 39.2 206.9 385.8 219.2 46.8 7.3 6.9 13.4 10.1 9.7 11.8
#  235.2 0.7 24.1 16.1 20.5 80.4 56.2 10 4 3.1 175.6 8.6 462.4 5.1 25 15.1 2
#  28.4 423.9]
# 2017:  ['온실가스 배출량' nan 608.1 37.7 34.7 91.8 8.8 10069.4 2305.1 546.1 803.8 266 65
#  1144.6 25.1 239.5 111.7 27.3 229.6 87.2 208.3 127.9 105 605.1 36.8 257.5
#  139.7 216.4 127.3 202.2 12.1 624 490.5 5177.8 196.9 28.3 472 88.6 85.2
#  26.8 43.8 8.4 54.5 23.7 6.2 258.8 33.8 16.8 320.5 733.6 332.3 157.2 38.5
#  314 75.3 2057.4 14.1 38.8 180 372.1 220.9 42.7 7.5 7.6 13.2 10.4 10.6
#  12.9 249.3 0.8 25 10.2 17.6 20.6 101.2 59 4 2.9 176.4 8.2 473.5 5 24.4
#  15.7 1.7 29 429.8 34]
# ...

# %%
#d의 0행 제거 및 타입 변경
d.drop(index =0, inplace = True)
d.fillna(0, inplace = True)
d.replace("-", 0)
d.iloc[:,5].replace('-',0)
# Out:
# 1       0.0
# 2     578.6
# 3      40.9
# 4       0.0
# 5       0.0
#       ...
# 89      0.0
# 90      0.0
# 91      0.0
# 92    424.4
# 93     34.8
# Name: 2020, Length: 93, dtype: float64

# %%
# d.iloc[:,2:].astype('float')
# print("2016: ",d.iloc[:,1].unique())
# print("2017: ",d.iloc[:,2].unique())
# print("2018: ",d.iloc[:,3].unique())
# print("2019: ",d.iloc[:,4].unique())
# print("2020: ",d.iloc[:,5].unique())

# d.iloc[:,5].replace("-",0).astype('float')
# d.info()
d.drop(["2020"], axis = 1, inplace = True)

# %%
#국가별 온실가스 배출량(2016~2020)
d["합계"] = d.sum()
d
# d["합계"].astype('float')
# Out:
#            국가별   2016   2017   2018   2019   합계
# 1          아시아    0.0    0.0    0.0    0.0  NaN
# 2      　　　대한민국  596.9  608.1  614.0  593.7  NaN
# 3    　　　아제르바이잔   38.5   37.7   38.6   41.8  NaN
# 4       　　　바레인   34.5   34.7   34.9   37.6  NaN
# 5     　　　방글라데시   86.7   91.8   95.3  102.7  NaN
# ..         ...    ...    ...    ...    ...  ...
# 89       　　　토고    2.0    1.7    2.0    2.0  NaN
# 90      　　　튀니지   28.4   29.0   29.0   29.0  NaN
# 91       오세아니아    0.0    0.0    0.0    0.0  NaN
# 92  　　　오스트레일리아  423.9  429.8  428.1  430.1  NaN
# 93     　　　뉴질랜드   32.2   34.0   33.5   35.1  NaN
#
# [93 rows x 6 columns]

# %%
d.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 1 to 93
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   국가별     93 non-null     object
#  1   2016    93 non-null     float64
#  2   2017    93 non-null     float64
#  3   2018    93 non-null     float64
#  4   2019    93 non-null     float64
#  5   합계      0 non-null      object
# dtypes: float64(4), object(2)
# memory usage: 4.5+ KB

# %%
cargroup = car.groupby("년도")[['승용', '승합', '화물', '특수']].sum()
print(cargroup)
# Out:
#          승용     승합     화물    특수
# 년도
# 2012  38523   9834  27909  4341
# 2013  38586   9659  28668  4423
# 2014  40859   9871  30300  4693
# 2015  43096   9833  30442  4634
# 2016  44326   9836  31811  4860
# 2017  40694  11158  26118  3644
# 2018  40506  10363  27796  3998
# 2019  41189   8020  27154  3914
# 2020  39794   8670  26486  3715

# %% [markdown]
# # 데이터 시각화

# %%
import matplotlib as mtl
import matplotlib.font_manager as fm

plt.rcParams['font.family'] ='Malgun Gothic'
plt.rcParams['axes.unicode_minus'] =False

# %%
import matplotlib.font_manager as fm

plotdata = e[e["Series Name"] == 2019]
plotlabel = list(e.columns)[1:]
plotvalue= list(e.iloc[39,1:])
print(plotlabel)
print(plotvalue)

plt.figure(figsize=(20,15))

# font_dirs = ['/usr/share/fonts/truetype/nanum', ]
# font_files = fm.findSystemFonts(fontpaths=font_dirs)

# for font_file in font_files:
#     fm.fontManager.addfont(font_file)
    
# sns.set(font="NanumBarunGothic", 
#         rc={"axes.unicode_minus":False},
#         style='darkgrid')

ax = plt.pie(plotvalue,  
             colors = sns.color_palette('pastel'), 
             autopct = "%.0f%%",
            startangle = 90,
            counterclock = False)
plt.legend(ax[0], plotlabel)
# plt.title("한국의 배출원별 탄소배출량(2019)")
plt.rc('font', size = 10)

plt.savefig("한국의 배출원별 탄소배출량(2019)")
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# ['Coal and coke CO2 emissions, South Korea, Annual', 'Petroleum and other liquids CO2 emissions, South Korea, Annual', 'CO2 emissions, South Korea, Annual', 'Consumed natural gas CO2 emissions, South Korea, Annual']
# [319.0, 256.0, 687.0, 112.0]

# %%
#국가별 온실가스 배출량(2016~2019)
#전세계 탄소배출량 추이
lst = []
for i in range(1,5):
    lst.append(d.iloc[:,i].sum())
    
#전세계 탄소배출량 중 한국의 배출량이 차지하느 비율
# kor_rate = []
# for i in range(1,5):
#     kor_rate.append(d.iloc[2,i]/d.iloc[:,1].sum())*100)

# %%
plotlabel_d1= ['2016','2017', '2018', '2019']
plotvalue_d1= lst
print(plotlabel_d1)
print(plotvalue_d1)

plt.figure(figsize=(10,10))
ax = sns.lineplot(x = plotlabel_d1, y = plotvalue_d1, color = "green", linewidth = 10)
ax = sns.set_style('whitegrid')
plt.legend(plotlabel)
# plt.title("전세계 탄소배출량 추이")
plt.rc('font', size = 10)

plt.savefig("전세계 탄소배출량 추이)")
# Out:
# findfont: Font family ['Malgun Gothic'] not found. Falling back to DejaVu Sans.
# ['2016', '2017', '2018', '2019']
# [32615.100000000002, 33034.4, 33842.200000000004, 33923.0]

# %%
#국가별 온실가스 배출량(2016~2019)
#전세계 탄소배출량 추이
# lst = []
# for i in range(1,5):
#     lst.append(d.iloc[:,i].sum())
    
#전세계 탄소배출량 중 한국의 배출량이 차지하는 비율
kor_rate = []
for i in range(1,5):
    kor_rate.append((d.iloc[2,i]/d.iloc[:,1].sum())*100)

plotlabel_d2 = ['2016','2017', '2018', '2019']
plotvalue_d2= kor_rate
print(plotlabel_d2)
print(plotvalue_d2)

plt.figure(figsize=(14,10))
ax = sns.lineplot(x = plotlabel_d2, y = plotvalue_d2, color = "green", linewidth = 10)
ax = sns.set_style('whitegrid')
plt.legend(plotlabel)
# plt.title("전세계 탄소배출량 중 한국의 배출량이 차지하는 비율")
plt.rc('font', size = 10)

plt.savefig("전세계 탄소배출량 중 한국의 배출량이 차지하는 비율")
# Out:
# ['2016', '2017', '2018', '2019']
# [0.11804348292661987, 0.11559063133333948, 0.11835008937577993, 0.12816149574890157]

# %%
kor_rate
# Out:
# [0.11804348292661987,
#  0.11559063133333948,
#  0.11835008937577993,
#  0.12816149574890157]

# %%
#연도별 교통부문별 온실가스 배출량(2009~2018)

road_rate = [];
for i in range(2,12):
    road_rate.append((b.iloc[1,i]/b.iloc[0,i].sum())*100)

# print(road_rate)
# print(b)

# %%
plotlabel_b = ['2009','2010', '2011', '2012', '2013', '2014', '2015', '2016', '2017', '2018']
plotvalue_b = road_rate
plotvalue_volume = b.iloc[1, 2:]
# b_legend = ["도로부문 온실가스 배출 비율", "도로부문 온실가스 배출 추이"]
fig, ax1 = plt.subplots(figsize=(10,5))
ax1 = sns.lineplot(x = plotlabel_b, y = plotvalue_b, label = "Greenhouse Gas Emissions Ratio in Road Sector(%)")
ax1.set_ylabel("Greenhouse Gas Emissions Ratio in Road Sector(%)")
ax1.legend()

ax2 = ax1.twinx()
ax2 = sns.lineplot(plotlabel_b, y= plotvalue_volume, label= "Trend of greenhouse gas emissions in the road sector (tonCO2eq)")
ax2.set_ylabel("Trend of greenhouse gas emissions in the road sector(tonCO2eq)")
ax = sns.set_style('whitegrid')
ax2.legend()
# plt.title("도로부문 탄소 배출 변화")
# plt.rc('font', size = 11)

plt.show()
# plt.savefig("도로부문 탄소 배출 변화")
# Out:
# /Users/seonghyunbae/opt/anaconda3/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
print(b.iloc[1, 2:])
print(b)
# Out:
# 2009     80654585.100843
# 2010     83499024.646346
# 2011     83095098.273866
# 2012     82415733.678537
# 2013     84988434.117572
# 2014     84100997.963045
# 2015     88871494.950825
# 2016     92788890.104731
# 2017     92253766.595005
# 2018    100899739.298179
# Name: 1, dtype: object
#          부문            합계          2009          2010          2011  \
# 0     Total  9.313755e+08  8.648702e+07  9.188583e+07  8.942128e+07
# 1      Road  8.735678e+08  8.065459e+07  8.349902e+07  8.309510e+07
# 2  Railroad  2.517001e+07  2.761223e+06  1.986671e+06  2.862746e+06
# 3  Aviation  1.902367e+07  1.084874e+06  6.052340e+06  1.229149e+06
# 4  Shipping  1.361403e+07  1.986343e+06  3.477987e+05  2.234287e+06
#
#            2012          2013          2014          2015          2016  \
# 0  8.843068e+07  9.045161e+07  8.893694e+07  9.750790e+07  9.712282e+07
# 1  8.241573e+07  8.498843e+07  8.410100e+07  8.887149e+07  9.278889e+07
# ...

# %%
plotlabel_b_index = b.iloc[1:,0]
plotvalue_b_portion= list(b.iloc[1:,-1])
print([plotlabel_b_index])
print(plotvalue_b_portion)

fig, ax = plt.subplots(figsize=(20,20))

ax = plt.pie(plotvalue_b_portion,  
             colors = sns.color_palette('pastel'), 
             autopct = "%.0f%%",
            startangle = 90,
            counterclock = False)
plt.legend(ax[0], plotlabel_b_index)
# plt.title("Carbon Emissions by Transport Sector in Korea(2019)")
# plt.rc('font', size = 15)

plt.savefig("Carbon Emissions by Transport Sector in Korea(2019)")
# Out:
# [1        Road
# 2    Railroad
# 3    Aviation
# 4    Shipping
# Name: 부문, dtype: object]
# [100899739.29817894, 2728074.346155199, 1631860.303931338, 0.0]

# %%
year = [2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020]

# %%
fig, ax = plt.subplots(figsize=(20,6))
bar_width = 0.2

index = np.arange(9)

b1 = plt.bar(index, cargroup['승용'], bar_width, alpha=0.4, color='red', label='Cars')
b2 = plt.bar(index + bar_width, cargroup['승합'], bar_width, alpha=0.4, color='blue', label='Vans')
b3 = plt.bar(index + 2 * bar_width, cargroup['화물'], bar_width, alpha=0.4, color='green', label='Trucks')
b4 = plt.bar(index + 3 * bar_width, cargroup['특수'], bar_width, alpha=0.4, color='orange', label='Specials')

plt.xticks(np.arange(bar_width, 9 + bar_width, 1), year)

plt.xlabel('years', size = 13)
plt.ylabel('count', size = 13)
plt.legend(fontsize = 11)
plt.show()

# %%
plot_subgroup = pd.DataFrame(cargroup.loc[2018])
plotIndex_subgroup = ["Car", "Vans", "Truck", "Specials"]
plotValue_subgroup = list(plot_subgroup.loc[:,2018])
plotValue_subgroup.append((b[['2018']].iloc[0]-b[['2018']].iloc[1])/1220.615503)
plotIndex_subgroup.append("Other than the road sector")
#전체 도로 비중 중 승용차가 차지하는 비중
car_rate = cargroup.loc[[2018]]["승용"]/(cargroup.loc[[2018]].sum(axis = 1))
print(car_rate)
# Out:
# 년도
# 2018    0.490014
# dtype: float64

# %%
plotIndex_subgroup
# Out:
# ['Car', 'Vans', 'Truck', 'Specials', 'Other than the road sector']

# %%
fig, ax = plt.subplots(figsize = (10,12))

ax.axis('equal')
pie_outside= ax.pie(plotvalue_b_portion, radius = 1.3, 
             colors = sns.color_palette("Set3", 10), 
            labels = plotlabel_b_index,
            labeldistance = 0.8,
             autopct = "%.0f%%",
            pctdistance = 1,
#             startangle = 90,
#             counterclock = False
             wedgeprops=dict(width=0.4,edgecolor='w'))

ax.legend(plotlabel_b_index)


pie_inside = ax.pie(plotValue_subgroup, radius = 0.87, labels = plotIndex_subgroup, labeldistance = 0.75, autopct = '%1.1f%%',wedgeprops=dict(width=0.3,edgecolor='w'), colors = sns.color_palette("pastel"))
plt.rc('font', size = 10)
plt.title("Carbon Emissions by Transport Sector in Korea(2018)")
# Out:
# Text(0.5, 1.0, 'Carbon Emissions by Transport Sector in Korea(2018)')

# %% [markdown]
# # 데이터 분석 요약

# %% [markdown]
# - 교통 부문(도로, 철도, 해운, 항공 등) 탄소 배출에서 도로 부문 탄소 배출이 약 96%를 차지함
# - 도로 부문 탄소 배출 중 승용차가 차지하는 탄소 배출 비중은 49%
# - 전체 교통 부문 탄소 배출 중 승용차의 탄소 배출이 차지하는 비중은 47%
#
# </br>
# - 결론: 교통 부문에서 승용차가 차지하는 비중이 높은 것으로 확인되기에 승용차의 탄소 배출 감소가 전체 탄소 배출 감소에 영향을 미칠 것으로 생각됨.
